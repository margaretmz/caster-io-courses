# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 30, 11)
x
# Out:
# array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.])

# %%
y = x ** 2
y
# Out:
# array([  0.,   9.,  36.,  81., 144., 225., 324., 441., 576., 729., 900.])

# %%
plt.title("Some chart")
plt.xlabel("x label")
plt.ylabel("y label")
plt.plot(x, y, 'gs')

# %%
import matplotlib.image as mpimg

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d31ed584-ed3f-4ffb-b19d-2813dcd6f26b" name="files[]" multiple disabled />
#      <output id="result-d31ed584-ed3f-4ffb-b19d-2813dcd6f26b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving android.png to android (1).png

# %%
# !ls
# Out:
# 'android (1).png'   android.png   sample_data

# %%
image = mpimg.imread('android.png')

# %%
plt.imshow(image)
