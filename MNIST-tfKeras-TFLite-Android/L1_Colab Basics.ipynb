# %% [markdown]
# ## How to write TensorFlow python code in Colab
# This notebook contains basics of Colab - Python notebook running in the VM of Google Cloud. Some text here.

# %%
#@title
# Install a spcific version of TensorFlow
! pip install tensorflow==2.0.0-alpha0

# %% [markdown]
# This is a text cell

# %%
print("this is a code cell")

# %%
# Import TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# %%
tf.version.VERSION

# %% [markdown]
# ### See full documentation
# Prepend a library, method or variable with a question mark ?

# %%
# ?tf.keras

# %%
# ?tf.version.VERSION

# %% [markdown]
# ### See inline help

# %%
# Press Tab after after an open parenthesis to see inline help of function signature and docstring
print()
