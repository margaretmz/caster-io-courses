# %%
import numpy as np

# %%
my_list = [0,1,2,3,4,5,6,7]

# %%
my_array = np.array(my_list)

# %%
print(my_array)
# Out:
# [0 1 2 3 4 5 6 7]

# %%
np.argmax(my_array)
# Out:
# 7

# %%
np.argmin(my_array)
# Out:
# 0

# %%
print(my_array)
# Out:
# [0 1 2 3 4 5 6 7]

# %%
print(my_array[:4])
# Out:
# [0 1 2 3]

# %%
print(my_array[4:])
# Out:
# [4 5 6 7]

# %%
print(my_array[4:6])
# Out:
# [4 5]

# %%
print(my_array.shape)
# Out:
# (8,)

# %%
reshaped_array = np.reshape(my_array, (2,4))

# %%
print(reshaped_array)
# Out:
# [[0 1 2 3]
#  [4 5 6 7]]

# %%
reshaped_array = np.reshape(my_array, (4,2))

# %%
print(reshaped_array)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]
#  [6 7]]
