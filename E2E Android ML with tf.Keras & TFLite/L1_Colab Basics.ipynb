# %% [markdown]
# This notebook contains some basics in Colab.

# %%
print("Hello machine learning!")

# %%
# Import TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# %%
tf.version.VERSION
